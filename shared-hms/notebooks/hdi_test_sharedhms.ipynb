# %%
# %%configure -f
# {
#     "conf":{
#         "spark.jars.packages": "io.delta:delta-core_2.12:1.0.1",
#         "spark.sql.extensions":"io.delta.sql.DeltaSparkSessionExtension"
#     }
# }
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>3</td><td>application_1677790499131_0011</td><td>pyspark3</td><td>idle</td><td><a target="_blank" href="http://hn0-sparks.4rgqet1mux1ulb2ok5ta0loelh.fx.internal.cloudapp.net:8088/proxy/application_1677790499131_0011/">Link</a></td><td><a target="_blank" href="http://wn3-sparks.4rgqet1mux1ulb2ok5ta0loelh.fx.internal.cloudapp.net:30060/node/containerlogs/container_1677790499131_0011_01_000001/livy">Link</a></td><td>✔</td></tr></table>
# SparkSession available as 'spark'.
# Current session configs: <tt>{u'kind': 'pyspark3', u'conf': {u'spark.jars.packages': u'io.delta:delta-core_2.12:1.0.1', u'spark.sql.extensions': u'io.delta.sql.DeltaSparkSessionExtension'}}</tt><br>
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>3</td><td>application_1677790499131_0011</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://hn0-sparks.4rgqet1mux1ulb2ok5ta0loelh.fx.internal.cloudapp.net:8088/proxy/application_1677790499131_0011/">Link</a></td><td><a target="_blank" href="http://wn3-sparks.4rgqet1mux1ulb2ok5ta0loelh.fx.internal.cloudapp.net:30060/node/containerlogs/container_1677790499131_0011_01_000001/livy">Link</a></td><td>✔</td></tr></table>

# %%
spark.version
# Out:
# '3.1.3.5.0.7.6'

# %%
# %%sql
# SHOW DATABASES
# Out:
# VBox(children=(HBox(children=(HTML(value=u'Type:'), Button(description=u'Table', layout=Layout(width=u'70px'),…
# Output()

# %%
# %%sql
# SHOW TABLES in sharedhmsdb
# Out:
# VBox(children=(HBox(children=(HTML(value=u'Type:'), Button(description=u'Table', layout=Layout(width=u'70px'),…
# Output()

# %%
# %%sql
# SELECT COUNT(*) FROM sharedhmsdb.building_summary
# Out:
# VBox(children=(HBox(children=(HTML(value=u'Type:'), Button(description=u'Table', layout=Layout(width=u'70px'),…
# Output()
